# %%
import gspread
from pathlib import Path
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from time import time, gmtime, sleep
import sys
sys.path.append("/home/jovyan/HSE-Bioinformatics")
sys.path.append("/home/jovyan/diploma_scripts/scripts")
from bio import *
import dcona_runs
import dcona

# %%
SHARED_PATH = Path('/home/jovyan/shared')
TCGA_PATH = SHARED_PATH / 'TCGA_data'
OUTPUT_PATH = SHARED_PATH / 'narek/outputs'
BRCA_DATA = SHARED_PATH / 'narek/Diplom2/data_BRCA'

annotation = rt(BRCA_DATA/'annotation.tsv')

# %%
def adjust_permute(df):
    df = df.copy()
    df['AdjPermutePvalue'] = df['PermutePvalue'] / round(df.rank(axis=0)["PermutePvalue"]) * df.shape[0]
    print('Pairs:', df.shape[0], '| after cut:', pvalue_cutoff(df, 'AdjPermutePvalue').shape[0])
    return df.sort_values('AdjPermutePvalue')

def pvalue_cutoff(df, by: str, alpha: float = 0.05):
    return df.loc[df[by] <= alpha]

def scatter_gene_pairs(ztest_df, row_ind, expr_matrix, annot):
    annot = annot.copy(); expr_matrix = expr_matrix.copy()
    gene1, gene2 = ztest_df.loc[row_ind, ['Source', 'Target']]
    annot[gene1] = expr_matrix.loc[gene1, annot['Sample']].to_numpy()
    annot[gene2] = expr_matrix.loc[gene2, annot['Sample']].to_numpy()
    return sns.lmplot(data=annot, x=gene1, y=gene2, hue="Group")

def wrapped_hypergeom(df):
    df = df.copy()
    df['Pvalue'] = df['PermutePvalue']
    df['AdjPvalue'] = df['AdjPermutePvalue']
    df_hyper = dcona.hypergeom(df).sort_values('Diff', ascending=False)
    return df_hyper

# %% [markdown]
# # BRCA

# %% [markdown]
# ## AGO2 (ENST00000220592)

# %% [markdown]
# ### Normal (exp 1)

# %%
ts_n = rc(OUTPUT_PATH/'experiments/1/ztest_ts.csv')
ts_n = adjust_permute(ts_n)
# Out:
# Pairs: 488477 | after cut: 0

# %%
pvalue_cutoff(ts_n, 'AdjPermutePvalue')
# Out:
# Empty DataFrame
# Columns: [Source, Target, RefCorr, RefPvalue, ExpCorr, ExpPvalue, Statistic, Pvalue, AdjPvalue, PermutePvalue, AdjPermutePvalue]
# Index: []

# %%
rna22_n = rc(OUTPUT_PATH/'experiments/1/ztest_rna22.csv')
rna22_n = adjust_permute(rna22_n)
# Out:
# Pairs: 513659 | after cut: 0

# %%
pvalue_cutoff(rna22_n, 'AdjPermutePvalue')
# Out:
# Empty DataFrame
# Columns: [Source, Target, RefCorr, RefPvalue, ExpCorr, ExpPvalue, Statistic, Pvalue, AdjPvalue, PermutePvalue, AdjPermutePvalue]
# Index: []

# %% [markdown]
# ### Luminal A (exp 2)

# %% [markdown]
# #### TargetScan

# %%
ts_a = rc(OUTPUT_PATH/'experiments/2/ztest_ts.csv')
ts_a = adjust_permute(ts_a)
# Out:
# Pairs: 455889 | after cut: 766

# %%
pvalue_cutoff(ts_a, 'AdjPermutePvalue').head()
# Out:
#                Source           Target   RefCorr     RefPvalue   ExpCorr  \
# 738  hsa-miR-93-5p|+3  ENST00000372088  0.675655  5.203258e-08 -0.316405
# 18   hsa-miR-93-5p|+3  ENST00000300146  0.639292  4.003818e-07 -0.339918
# 15   hsa-miR-93-5p|+3  ENST00000225388  0.623995  8.738832e-07 -0.295899
# 22   hsa-miR-93-5p|+3  ENST00000295951  0.638515  4.170186e-07 -0.361312
# 6    hsa-miR-93-5p|+3  ENST00000264033  0.598911  2.885452e-06 -0.393096
#
#      ExpPvalue  Statistic    Pvalue  AdjPvalue  PermutePvalue  \
# 738   0.019925   1.148722  0.000001   0.560617            0.0
# 18    0.012218   1.110976  0.000003   0.247410            0.0
# 15    0.029742   1.036541  0.000012   0.238420            0.0
# 22    0.007607   1.134056  0.000002   0.254892            0.0
# 6     0.003567   1.106905  0.000003   0.224219            0.0
#
#      AdjPermutePvalue
# 738               0.0
# 18                0.0
# 15                0.0
# 22                0.0
# 6                 0.0

# %%
ts_a_hyper = pvalue_cutoff(wrapped_hypergeom(ts_a), 'AdjPvalue')
ts_a_hyper.to_csv(OUTPUT_PATH/'hypergeom/2_ts.csv', index=False)
ts_a_hyper
# Out:
#              Molecule  Diff  Total  Proportion        Pvalue     AdjPvalue
# 0    hsa-miR-93-5p|+3   215   3927    0.054749  0.000000e+00  0.000000e+00
# 6   hsa-miR-23a-3p|+1   167   4386    0.038076  0.000000e+00  0.000000e+00
# 2   hsa-miR-140-3p|+1    51   4703    0.010844  0.000000e+00  0.000000e+00
# 7    hsa-miR-140-3p|0    46   4246    0.010834  0.000000e+00  0.000000e+00
# 9   hsa-miR-23b-3p|+1    36   4386    0.008208  1.909584e-14  2.100542e-13
# 13   hsa-miR-22-3p|+1    30   3424    0.008762  5.789813e-13  5.307329e-12
# 3    hsa-miR-26b-5p|0    24   3864    0.006211  8.175053e-08  6.423256e-07
# 5    hsa-miR-128-3p|0    21   4445    0.004724  3.180566e-05  2.186639e-04
# 4     hsa-miR-17-3p|0    19   4762    0.003990  5.959461e-04  3.277703e-03
# 15   hsa-miR-361-3p|0    19   4180    0.004545  1.216044e-04  7.431377e-04

# %% [markdown]
# #### RNA22

# %%
rna22_a = rc(OUTPUT_PATH/'experiments/2/ztest_rna22.csv')
rna22_a = adjust_permute(rna22_a)
# Out:
# Pairs: 483291 | after cut: 848

# %%
rna22_a
# Out:
#                    Source           Target   RefCorr     RefPvalue   ExpCorr  \
# 0        hsa-miR-93-5p|+3  ENST00000298068  0.747537  3.287528e-10 -0.408407
# 1        hsa-miR-93-5p|+3  ENST00000465503  0.530788  4.748792e-05 -0.544088
# 28       hsa-miR-361-3p|0  ENST00000620918 -0.420599  1.585994e-03  0.562201
# 4        hsa-miR-93-5p|+3  ENST00000454497  0.549391  2.339158e-05 -0.467327
# 6        hsa-miR-93-5p|+3  ENST00000295951  0.638515  4.170186e-07 -0.361312
# ...                   ...              ...       ...           ...       ...
# 480564  hsa-miR-181b-5p|0  ENST00000351193  0.022621  8.679694e-01  0.022625
# 483288   hsa-miR-134-5p|0  ENST00000593035  0.201841  1.365443e-01  0.201845
# 483284  hsa-miR-29a-3p|-1  ENST00000319854  0.060021  6.590726e-01  0.060014
# 483286  hsa-miR-30a-3p|+1  ENST00000430952 -0.186803  1.684917e-01 -0.186808
# 480571    hsa-miR-25-3p|0  ENST00000370475  0.066502  6.249313e-01  0.066507
#
#         ExpPvalue  Statistic        Pvalue  AdjPvalue  PermutePvalue  \
# 0        0.002418   1.401047  3.292676e-09   0.001591       0.000000
# 1        0.000034   1.201186  3.929732e-07   0.063307       0.000000
# 28       0.000017  -1.084465  4.662105e-06   0.204832       0.000000
# 4        0.000461   1.124154  2.064119e-06   0.142510       0.000000
# 6        0.007607   1.134056  1.677328e-06   0.162127       0.000000
# ...           ...        ...           ...        ...            ...
# 480564   0.869166  -0.000004  9.999881e-01   0.999998       0.999988
# 483288   0.140221  -0.000005  9.999840e-01   1.000000       0.999982
# 483284   0.662083   0.000007  9.999764e-01   1.000000       0.999974
# 483286   0.172476   0.000005  9.999834e-01   1.000000       0.999982
# 480571   0.628130  -0.000005  9.999841e-01   0.999999       0.999980
#
#         AdjPermutePvalue
# 0               0.000000
# 1               0.000000
# 28              0.000000
# 4               0.000000
# 6               0.000000
# ...                  ...
# 480564          0.999998
# 483288          0.999999
# 483284          0.999999
# 483286          1.000001
# 480571          1.000001
#
# [483291 rows x 11 columns]

# %%
pvalue_cutoff(rna22_a, 'AdjPermutePvalue').head()
# Out:
#               Source           Target   RefCorr     RefPvalue   ExpCorr  \
# 0   hsa-miR-93-5p|+3  ENST00000298068  0.747537  3.287528e-10 -0.408407
# 1   hsa-miR-93-5p|+3  ENST00000465503  0.530788  4.748792e-05 -0.544088
# 28  hsa-miR-361-3p|0  ENST00000620918 -0.420599  1.585994e-03  0.562201
# 4   hsa-miR-93-5p|+3  ENST00000454497  0.549391  2.339158e-05 -0.467327
# 6   hsa-miR-93-5p|+3  ENST00000295951  0.638515  4.170186e-07 -0.361312
#
#     ExpPvalue  Statistic        Pvalue  AdjPvalue  PermutePvalue  \
# 0    0.002418   1.401047  3.292676e-09   0.001591            0.0
# 1    0.000034   1.201186  3.929732e-07   0.063307            0.0
# 28   0.000017  -1.084465  4.662105e-06   0.204832            0.0
# 4    0.000461   1.124154  2.064119e-06   0.142510            0.0
# 6    0.007607   1.134056  1.677328e-06   0.162127            0.0
#
#     AdjPermutePvalue
# 0                0.0
# 1                0.0
# 28               0.0
# 4                0.0
# 6                0.0

# %%
rna22_a_hyper = pvalue_cutoff(wrapped_hypergeom(rna22_a), 'AdjPvalue')
rna22_a_hyper.to_csv(OUTPUT_PATH/'hypergeom/2_rna22.csv', index=False)
rna22_a_hyper
# Out:
#              Molecule  Diff  Total  Proportion        Pvalue     AdjPvalue
# 0    hsa-miR-93-5p|+3   355   6280    0.056529  0.000000e+00  0.000000e+00
# 5   hsa-miR-23a-3p|+1    88   2865    0.030716  0.000000e+00  0.000000e+00
# 4    hsa-miR-22-3p|+1    41   4295    0.009546  0.000000e+00  0.000000e+00
# 2     hsa-let-7g-5p|0    34   6267    0.005425  1.461551e-08  1.558988e-07
# 19    hsa-let-7d-5p|0    30   6935    0.004326  9.310300e-06  5.958592e-05
# 8    hsa-miR-128-3p|0    27   5286    0.005108  1.354451e-06  1.083561e-05
# 6    hsa-miR-140-3p|0    26   2297    0.011319  1.940670e-13  3.105072e-12
# 7   hsa-miR-140-3p|+1    25   2928    0.008538  2.064986e-10  2.643182e-09
# 12  hsa-miR-23b-3p|+1    18   2741    0.006567  2.826794e-06  2.010165e-05
# 1    hsa-miR-361-3p|0    17   3871    0.004392  6.463510e-04  3.760588e-03
# 10    hsa-miR-17-3p|0    17   4416    0.003850  2.563100e-03  1.366987e-02
# 3    hsa-miR-26b-5p|0    17   1909    0.008905  8.748138e-08  7.998297e-07

# %% [markdown]
# ### Luminal B (exp 3)

# %% [markdown]
# #### TargetScan

# %%
ts_b = rc(OUTPUT_PATH/'experiments/3/ztest_ts.csv')
ts_b = adjust_permute(ts_b)
# Out:
# Pairs: 446066 | after cut: 0

# %%
pvalue_cutoff(ts_b, 'AdjPermutePvalue')
# Out:
# Empty DataFrame
# Columns: [Source, Target, RefCorr, RefPvalue, ExpCorr, ExpPvalue, Statistic, Pvalue, AdjPvalue, PermutePvalue, AdjPermutePvalue]
# Index: []

# %% [markdown]
# #### RNA22

# %%
rna22_b = rc(OUTPUT_PATH/'experiments/3/ztest_rna22.csv')
rna22_b = adjust_permute(rna22_b)
# Out:
# Pairs: 470265 | after cut: 0

# %%
pvalue_cutoff(rna22_b, 'AdjPermutePvalue')
# Out:
# Empty DataFrame
# Columns: [Source, Target, RefCorr, RefPvalue, ExpCorr, ExpPvalue, Statistic, Pvalue, AdjPvalue, PermutePvalue, AdjPermutePvalue]
# Index: []

# %% [markdown]
# ### Basal-like (exp 4)

# %% [markdown]
# TargetScan

# %%
ts_bl = rc(OUTPUT_PATH/'experiments/4/ztest_ts.csv')
ts_bl = adjust_permute(ts_bl)
# Out:
# Pairs: 429421 | after cut: 0

# %%
pvalue_cutoff(ts_bl, 'AdjPermutePvalue')
# Out:
# Empty DataFrame
# Columns: [Source, Target, RefCorr, RefPvalue, ExpCorr, ExpPvalue, Statistic, Pvalue, AdjPvalue, PermutePvalue, AdjPermutePvalue]
# Index: []

# %% [markdown]
# RNA22

# %%
rna22_bl = rc(OUTPUT_PATH/'experiments/4/ztest_rna22.csv')
rna22_bl = adjust_permute(rna22_bl)
# Out:
# Pairs: 448281 | after cut: 1

# %%
pvalue_cutoff(rna22_bl, 'AdjPermutePvalue')
# Out:
#              Source           Target   RefCorr  RefPvalue   ExpCorr  \
# 0  hsa-miR-93-5p|+3  ENST00000382363 -0.687055    0.00001  0.513276
#
#    ExpPvalue  Statistic    Pvalue  AdjPvalue  PermutePvalue  AdjPermutePvalue
# 0   0.001879  -1.409525  0.000002   0.933916            0.0               0.0

# %% [markdown]
# ## DROSHA (ENST00000513349)

# %% [markdown]
# ### Normal (exp 5)

# %% [markdown]
# TargetScan

# %%
ts_n = rc(OUTPUT_PATH/'experiments/5/ztest_ts.csv')
ts_n = adjust_permute(ts_n)
# Out:
# Pairs: 488477 | after cut: 0

# %%
pvalue_cutoff(ts_n, 'AdjPermutePvalue')
# Out:
# Empty DataFrame
# Columns: [Source, Target, RefCorr, RefPvalue, ExpCorr, ExpPvalue, Statistic, Pvalue, AdjPvalue, PermutePvalue, AdjPermutePvalue]
# Index: []

# %% [markdown]
# RNA22

# %%
rna22_bl = rc(OUTPUT_PATH/'experiments/5/ztest_rna22.csv')
rna22_bl = adjust_permute(rna22_bl)
# Out:
# Pairs: 513659 | after cut: 0

# %%
pvalue_cutoff(rna22_bl, 'AdjPermutePvalue')
# Out:
# Empty DataFrame
# Columns: [Source, Target, RefCorr, RefPvalue, ExpCorr, ExpPvalue, Statistic, Pvalue, AdjPvalue, PermutePvalue, AdjPermutePvalue]
# Index: []

# %% [markdown]
# ### Luminal A (exp 6)

# %% [markdown]
# TargetScan

# %%
ts_n = rc(OUTPUT_PATH/'experiments/6/ztest_ts.csv')
ts_n = adjust_permute(ts_n)
# Out:
# Pairs: 455889 | after cut: 236

# %%
pvalue_cutoff(ts_n, 'AdjPermutePvalue')
# Out:
#                 Source           Target   RefCorr     RefPvalue   ExpCorr  \
# 15   hsa-miR-23a-3p|+1  ENST00000353379 -0.647340  2.742449e-09  0.127795
# 102  hsa-miR-23a-3p|+1  ENST00000288828 -0.565036  4.546116e-07  0.322873
# 49    hsa-miR-140-3p|0  ENST00000246802  0.675847  3.198984e-10 -0.020370
# 83    hsa-miR-361-3p|0  ENST00000512944  0.570213  3.427588e-07 -0.254139
# 9     hsa-miR-93-5p|+3  ENST00000605895 -0.551209  9.456138e-07  0.249474
# ..                 ...              ...       ...           ...       ...
# 763  hsa-miR-140-3p|+1  ENST00000312579  0.502532  9.915333e-06 -0.092091
# 484  hsa-miR-1307-3p|0  ENST00000221922  0.390185  7.512160e-04 -0.325491
# 59   hsa-miR-23a-3p|+1  ENST00000319004 -0.569331  3.597662e-07  0.141280
# 454  hsa-miR-140-3p|+1  ENST00000327761  0.599147  6.474714e-08  0.016216
# 384  hsa-miR-23a-3p|+1  ENST00000333676 -0.461678  5.609379e-05  0.244922
#
#      ExpPvalue  Statistic    Pvalue  AdjPvalue  PermutePvalue  \
# 15    0.277517  -0.899204  0.000011   0.602310       0.000000
# 102   0.005605  -0.975051  0.000002   0.812144       0.000000
# 49    0.862770   0.841801  0.000037   0.679102       0.000000
# 83    0.030007   0.907672  0.000009   0.795187       0.000000
# 9     0.033204  -0.874968  0.000018   0.591190       0.000000
# ..         ...        ...       ...        ...            ...
# 763   0.434224   0.645041  0.001577   0.927935       0.000025
# 484   0.005221   0.749795  0.000240   0.880547       0.000025
# 59    0.229790  -0.788765  0.000111   0.770037       0.000025
# 454   0.890555   0.675597  0.000934   0.872388       0.000025
# 384   0.036597  -0.749446  0.000241   0.858758       0.000026
#
#      AdjPermutePvalue
# 15           0.000000
# 102          0.000000
# 49           0.000000
# 83           0.000000
# 9            0.000000
# ..                ...
# 763          0.049138
# 484          0.049142
# 59           0.049359
# 454          0.049359
# 384          0.049576
#
# [236 rows x 11 columns]

# %%
ts_n_hyper = pvalue_cutoff(wrapped_hypergeom(ts_n), 'AdjPvalue')
ts_n_hyper.to_csv(OUTPUT_PATH/'hypergeom/6_ts.csv', index=False)
ts_n_hyper
# Out:
#              Molecule  Diff  Total  Proportion        Pvalue     AdjPvalue
# 1    hsa-miR-140-3p|0    42   4246    0.009892  0.000000e+00  0.000000e+00
# 4     hsa-miR-16-5p|0    30   4347    0.006901  0.000000e+00  0.000000e+00
# 3    hsa-miR-93-5p|+3    29   3927    0.007385  0.000000e+00  0.000000e+00
# 0   hsa-miR-23a-3p|+1    27   4386    0.006156  0.000000e+00  0.000000e+00
# 6   hsa-miR-1307-3p|0    19   1815    0.010468  0.000000e+00  0.000000e+00
# 14  hsa-miR-140-3p|+1    18   4703    0.003827  8.375611e-11  3.589548e-10
# 5    hsa-miR-191-5p|0    12    906    0.013245  1.102451e-13  5.512257e-13
# 2    hsa-miR-361-3p|0    11   4180    0.002632  1.449172e-05  5.434396e-05
# 11    hsa-miR-17-3p|0    10   4762    0.002100  2.214371e-04  7.381237e-04
# 15    hsa-let-7b-5p|0     5   2604    0.001920  1.200448e-02  3.601343e-02

# %% [markdown]
# RNA22

# %%
rna22_la = rc(OUTPUT_PATH/'experiments/6/ztest_rna22.csv')
rna22_la = adjust_permute(rna22_la)
# Out:
# Pairs: 483291 | after cut: 822

# %%
pvalue_cutoff(rna22_la, 'AdjPermutePvalue')
# Out:
#                  Source           Target   RefCorr     RefPvalue   ExpCorr  \
# 19    hsa-miR-1307-3p|0  ENST00000391759  0.535022  2.145514e-06 -0.356216
# 2      hsa-miR-93-5p|+3  ENST00000177648  0.565462  4.442301e-07 -0.295676
# 114    hsa-miR-361-3p|0  ENST00000394780 -0.458492  6.368733e-05  0.469246
# 109    hsa-miR-191-5p|0  ENST00000383811 -0.458862  6.275934e-05  0.447568
# 5      hsa-miR-93-5p|+3  ENST00000440600  0.678208  2.648289e-10 -0.142532
# ...                 ...              ...       ...           ...       ...
# 787    hsa-miR-191-5p|0  ENST00000325167 -0.513257  6.078106e-06  0.107624
# 1408  hsa-miR-99b-5p|+1  ENST00000381793  0.390469  7.442373e-04 -0.217724
# 758   hsa-miR-1307-3p|0  ENST00000299275 -0.544467  1.336678e-06  0.070555
# 1193   hsa-miR-342-3p|0  ENST00000529064 -0.116529  3.222037e-01  0.481081
# 1169   hsa-miR-30e-3p|0  ENST00000450736  0.395164  6.373129e-04 -0.225576
#
#       ExpPvalue  Statistic        Pvalue  AdjPvalue  PermutePvalue  \
# 19     0.002174   0.969700  2.028749e-06   0.326825       0.000000
# 2      0.011362   0.945601  3.613085e-06   0.218271       0.000000
# 114    0.000041  -1.004504  8.608383e-07   0.416035       0.000000
# 109    0.000098  -0.977523  1.677256e-06   0.405301       0.000000
# 5      0.225674   0.969297  2.048624e-06   0.247520       0.000000
# ...         ...        ...           ...        ...            ...
# 787    0.360648  -0.675185  9.405946e-04   0.569650       0.000084
# 1408   0.063505   0.633620  1.908657e-03   0.655605       0.000085
# 758    0.549221  -0.681155  8.469939e-04   0.566175       0.000085
# 1193   0.000025  -0.641451  1.675377e-03   0.640075       0.000085
# 1169   0.054448   0.647428  1.515309e-03   0.635708       0.000085
#
#       AdjPermutePvalue
# 19            0.000000
# 2             0.000000
# 114           0.000000
# 109           0.000000
# 5             0.000000
# ...                ...
# 787           0.049878
# 1408          0.049939
# 758           0.049939
# 1193          0.050000
# 1169          0.050000
#
# [822 rows x 11 columns]

# %%
rna22_la_hyper = pvalue_cutoff(wrapped_hypergeom(rna22_la), 'AdjPvalue')
rna22_la_hyper.to_csv(OUTPUT_PATH/'hypergeom/6_rna22.csv', index=False)
rna22_la_hyper
# Out:
#              Molecule  Diff  Total  Proportion        Pvalue     AdjPvalue
# 0   hsa-miR-1307-3p|0   183   7043    0.025983  0.000000e+00  0.000000e+00
# 1    hsa-miR-93-5p|+3   127   6280    0.020223  0.000000e+00  0.000000e+00
# 8     hsa-let-7b-5p|0    72   7553    0.009533  0.000000e+00  0.000000e+00
# 6   hsa-miR-23a-3p|+1    59   2865    0.020593  0.000000e+00  0.000000e+00
# 5    hsa-miR-140-3p|0    41   2297    0.017849  0.000000e+00  0.000000e+00
# 11  hsa-miR-140-3p|+1    28   2928    0.009563  6.044054e-13  5.612336e-12
# 12    hsa-miR-17-3p|0    26   4416    0.005888  8.606815e-08  5.594430e-07
# 4   hsa-miR-99b-5p|+1    25   1897    0.013179  1.021405e-14  1.106522e-13
# 13    hsa-let-7i-5p|0    22   7176    0.003066  6.829917e-03  2.611439e-02
# 10    hsa-miR-16-5p|0    18   1825    0.009863  4.964450e-09  3.585436e-08
# 2    hsa-miR-361-3p|0    18   3871    0.004650  1.607580e-04  9.499339e-04
# 20    hsa-miR-93-5p|0    17   4162    0.004085  1.006372e-03  5.031862e-03
# 24   hsa-miR-22-3p|+1    16   4295    0.003725  3.423293e-03  1.483427e-02
# 18   hsa-miR-20a-5p|0    12   2430    0.004938  1.147988e-03  5.329945e-03
# 3    hsa-miR-191-5p|0    10    390    0.025641  2.145025e-09  1.742833e-08
# 26   hsa-miR-30e-5p|0     8   1133    0.007061  8.389630e-04  4.544383e-03
# 32  hsa-miR-181a-5p|0     8   1496    0.005348  4.592449e-03  1.865682e-02

# %% [markdown]
# ## DICER1 (ENST00000393063)

# %% [markdown]
# ### Normal (exp 7)

# %% [markdown]
# TargetScan

# %%
ts_n = rc(OUTPUT_PATH/'experiments/7/ztest_ts.csv')
ts_n = adjust_permute(ts_n)
# Out:
# Pairs: 488477 | after cut: 0

# %%
pvalue_cutoff(ts_n, 'AdjPermutePvalue')
# Out:
# Empty DataFrame
# Columns: [Source, Target, RefCorr, RefPvalue, ExpCorr, ExpPvalue, Statistic, Pvalue, AdjPvalue, PermutePvalue, AdjPermutePvalue]
# Index: []

# %% [markdown]
# RNA22

# %%
rna22_n = rc(OUTPUT_PATH/'experiments/7/ztest_rna22.csv')
rna22_n = adjust_permute(rna22_n)
# Out:
# Pairs: 513659 | after cut: 16

# %%
pvalue_cutoff(rna22_n, 'AdjPermutePvalue')
# Out:
#                 Source           Target   RefCorr  RefPvalue   ExpCorr  \
# 518  hsa-miR-1307-5p|0  ENST00000413266 -0.301210   0.107666  0.802016
# 549  hsa-miR-1307-5p|0  ENST00000420936 -0.232661   0.215917  0.768548
# 6    hsa-miR-1307-5p|0  ENST00000261772 -0.356452   0.055758  0.829839
# 514   hsa-miR-15a-5p|0  ENST00000013807 -0.610887   0.000559  0.636290
# 523  hsa-miR-1307-5p|0  ENST00000564370 -0.378226   0.041906  0.732661
# 515  hsa-miR-1307-5p|0  ENST00000373053 -0.367339   0.048432  0.790323
# 7    hsa-miR-196a-5p|0  ENST00000356970  0.491129   0.007209 -0.682258
# 527  hsa-miR-1307-5p|0  ENST00000300737 -0.412500   0.025873  0.704435
# 0    hsa-miR-196a-5p|0  ENST00000554015  0.745968   0.000006 -0.401613
# 517  hsa-miR-1307-5p|0  ENST00000610179 -0.355242   0.056624  0.785484
# 516  hsa-miR-196a-5p|0  ENST00000265094  0.453226   0.013784 -0.736694
# 528  hsa-miR-1307-5p|0  ENST00000235329 -0.529032   0.003521  0.618548
# 3      hsa-miR-17-5p|0  ENST00000379103 -0.708468   0.000029  0.466935
# 1     hsa-miR-15a-5p|0  ENST00000330188 -0.470161   0.010400  0.711290
# 534  hsa-miR-1307-5p|0  ENST00000330836 -0.525000   0.003814  0.606452
# 521   hsa-miR-15a-5p|0  ENST00000336156 -0.601210   0.000713  0.568548
#
#         ExpPvalue  Statistic    Pvalue  AdjPvalue  PermutePvalue  \
# 518  3.722291e-07  -1.415087  0.000015   1.000000   0.000000e+00
# 549  2.275446e-06  -1.253772  0.000128   1.000000   0.000000e+00
# 6    5.957517e-08  -1.560433  0.000002   0.959528   0.000000e+00
# 514  2.851596e-04  -1.462251  0.000008   1.000000   9.734084e-07
# 523  1.131262e-05  -1.332437  0.000047   1.000000   9.734084e-07
# 515  7.305377e-07  -1.457634  0.000008   1.000000   9.734084e-07
# 7    7.141023e-05   1.370873  0.000028   0.963336   9.734084e-07
# 527  3.334066e-05  -1.314671  0.000059   1.000000   1.460113e-06
# 0    3.029203e-02   1.389372  0.000022   0.865243   1.168090e-06
# 517  9.522953e-07  -1.430960  0.000012   1.000000   1.265431e-06
# 516  9.580662e-06   1.431962  0.000012   1.000000   6.813859e-07
# 528  4.592664e-04  -1.311451  0.000062   1.000000   6.813859e-07
# 3    1.098351e-02  -1.390245  0.000022   0.926272   1.362772e-06
# 1    2.596209e-05  -1.400068  0.000019   0.883457   1.362772e-06
# 534  6.256456e-04  -1.286507  0.000085   1.000000   1.654794e-06
# 521  1.532094e-03  -1.340414  0.000042   1.000000   5.840450e-07
#
#      AdjPermutePvalue
# 518          0.000000
# 549          0.000000
# 6            0.000000
# 514          0.041667
# 523          0.041667
# 515          0.041667
# 7            0.041667
# 527          0.041667
# 0            0.042857
# 517          0.043333
# 516          0.043750
# 528          0.043750
# 3            0.043750
# 1            0.043750
# 534          0.044737
# 521          0.050000

# %%
rna22_n_hyper = pvalue_cutoff(wrapped_hypergeom(rna22_n), 'AdjPvalue')
rna22_n_hyper.to_csv(OUTPUT_PATH/'hypergeom/7_rna22.csv', index=False)
rna22_n_hyper
# Out:
#             Molecule  Diff  Total  Proportion        Pvalue     AdjPvalue
# 0  hsa-miR-1307-5p|0     9   3281    0.002743  2.220446e-16  8.881784e-16
# 1   hsa-miR-15a-5p|0     3   2557    0.001173  6.573344e-05  1.314669e-04
# 2  hsa-miR-196a-5p|0     3   4698    0.000639  3.916503e-04  5.222003e-04

# %% [markdown]
# ### Luminal A (exp 8)

# %% [markdown]
# TargetScan

# %%
ts_n = rc(OUTPUT_PATH/'experiments/8/ztest_ts.csv')
ts_n = adjust_permute(ts_n)
# Out:
# Pairs: 455889 | after cut: 0

# %%
pvalue_cutoff(ts_n, 'AdjPermutePvalue')
# Out:
# Empty DataFrame
# Columns: [Source, Target, RefCorr, RefPvalue, ExpCorr, ExpPvalue, Statistic, Pvalue, AdjPvalue, PermutePvalue, AdjPermutePvalue]
# Index: []

# %% [markdown]
# RNA22

# %%
rna22_n = rc(OUTPUT_PATH/'experiments/8/ztest_rna22.csv')
rna22_n = adjust_permute(rna22_n)
# Out:
# Pairs: 483291 | after cut: 0

# %%
pvalue_cutoff(rna22_n, 'AdjPermutePvalue')
# Out:
# Empty DataFrame
# Columns: [Source, Target, RefCorr, RefPvalue, ExpCorr, ExpPvalue, Statistic, Pvalue, AdjPvalue, PermutePvalue, AdjPermutePvalue]
# Index: []

# %% [markdown]
# ## DGCR8 (ENST00000351989)

# %% [markdown]
# ### Luminal A (exp 9)

# %% [markdown]
# TargetScan

# %%
ts_n = rc(OUTPUT_PATH/'experiments/9/ztest_ts.csv')
ts_n = adjust_permute(ts_n)
# Out:
# Pairs: 455889 | after cut: 743

# %%
pvalue_cutoff(ts_n, 'AdjPermutePvalue')
# Out:
#                 Source           Target   RefCorr     RefPvalue   ExpCorr  \
# 0     hsa-miR-140-3p|0  ENST00000308683  0.661223  9.917929e-10 -0.276444
# 38    hsa-miR-361-3p|0  ENST00000373316  0.460854  5.797451e-05 -0.406202
# 2    hsa-miR-23a-3p|+1  ENST00000319004 -0.616387  2.218929e-08  0.279431
# 3     hsa-miR-140-3p|0  ENST00000373314  0.661081  1.002455e-09 -0.233855
# 32    hsa-miR-191-5p|0  ENST00000245539 -0.542049  1.510759e-06  0.308250
# ..                 ...              ...       ...           ...       ...
# 690    hsa-miR-16-5p|0  ENST00000326195 -0.403499  4.814341e-04  0.248506
# 601  hsa-miR-193a-5p|0  ENST00000376573 -0.370811  1.394332e-03  0.293144
# 677  hsa-miR-10b-5p|+1  ENST00000342374  0.314054  7.093165e-03 -0.342475
# 426   hsa-miR-140-3p|0  ENST00000217402  0.478663  2.796023e-05 -0.196188
# 765    hsa-let-7i-5p|0  ENST00000409534  0.558891  6.319377e-07 -0.041821
#
#      ExpPvalue  Statistic        Pvalue  AdjPvalue  PermutePvalue  \
# 0     0.018097   1.078812  1.256515e-07   0.057283       0.000000
# 38    0.000439   0.929449  5.279833e-06   0.300877       0.000000
# 2     0.016866  -1.006222  8.245699e-07   0.093978       0.000000
# 3     0.046082   1.032995  4.178905e-07   0.095256       0.000000
# 32    0.008254  -0.925663  5.765717e-06   0.292059       0.000000
# ..         ...        ...           ...        ...            ...
# 690   0.033902  -0.681642  8.397433e-04   0.562985       0.000081
# 601   0.012099  -0.691365  7.066572e-04   0.535145       0.000081
# 677   0.003248   0.681931  8.354805e-04   0.561779       0.000081
# 426   0.094806   0.720013  4.197741e-04   0.476046       0.000081
# 765   0.722655   0.673064  9.761068e-04   0.577917       0.000081
#
#      AdjPermutePvalue
# 0            0.000000
# 38           0.000000
# 2            0.000000
# 3            0.000000
# 32           0.000000
# ..                ...
# 690          0.049932
# 601          0.049932
# 677          0.049933
# 426          0.049933
# 765          0.049933
#
# [743 rows x 11 columns]

# %%
ts_n_hyper = pvalue_cutoff(wrapped_hypergeom(ts_n), 'AdjPvalue')
ts_n_hyper.to_csv(OUTPUT_PATH/'hypergeom/9_ts.csv', index=False)
ts_n_hyper
# Out:
#              Molecule  Diff  Total  Proportion        Pvalue     AdjPvalue
# 0    hsa-miR-140-3p|0   169   4246    0.039802  0.000000e+00  0.000000e+00
# 4     hsa-miR-16-5p|0    76   4347    0.017483  0.000000e+00  0.000000e+00
# 9    hsa-miR-93-5p|+3    66   3927    0.016807  0.000000e+00  0.000000e+00
# 10  hsa-miR-140-3p|+1    58   4703    0.012333  0.000000e+00  0.000000e+00
# 6     hsa-miR-17-3p|0    42   4762    0.008820  0.000000e+00  0.000000e+00
# 1    hsa-miR-361-3p|0    38   4180    0.009091  0.000000e+00  0.000000e+00
# 8    hsa-miR-20a-5p|0    37   4863    0.007608  3.164136e-14  2.214895e-13
# 2   hsa-miR-23a-3p|+1    36   4386    0.008208  7.660539e-15  6.032674e-14
# 3    hsa-miR-191-5p|0    23    906    0.025386  0.000000e+00  0.000000e+00
# 13   hsa-miR-192-5p|0    15   3386    0.004430  5.769757e-04  3.304497e-03
# 20    hsa-miR-21-3p|0    12   3289    0.003649  8.825380e-03  3.706660e-02
# 12    hsa-let-7d-5p|0    12   2604    0.004608  1.425982e-03  7.186951e-03
# 27    hsa-let-7i-5p|0    12   2604    0.004608  1.425982e-03  7.186951e-03
# 11   hsa-miR-100-5p|0     9    653    0.013783  1.716559e-06  1.081432e-05
# 18   hsa-miR-210-3p|0     6    876    0.006849  3.443504e-03  1.549577e-02

# %% [markdown]
# RNA22

# %%
rna22_n = rc(OUTPUT_PATH/'experiments/9/ztest_rna22.csv')
rna22_n = adjust_permute(rna22_n)

# %%
pvalue_cutoff(rna22_n, 'AdjPermutePvalue')

# %% [markdown]
# ### Normal (exp 10)

# %% [markdown]
# TargetScan

# %%
ts_n = rc(OUTPUT_PATH/'experiments/10/ztest_ts.csv')
ts_n = adjust_permute(ts_n)
# Out:
# Pairs: 488477 | after cut: 193

# %%
pvalue_cutoff(ts_n, 'AdjPermutePvalue')
# Out:
#                   Source           Target   RefCorr     RefPvalue   ExpCorr  \
# 78     hsa-miR-151a-3p|0  ENST00000377893 -0.647177  2.097337e-04  0.508871
# 31     hsa-miR-200b-3p|0  ENST00000263923 -0.901210  4.159900e-11 -0.044758
# 16    hsa-miR-203a-3p|+1  ENST00000371158  0.867742  2.360165e-09 -0.235081
# 46     hsa-miR-151a-3p|0  ENST00000263636  0.611694  5.480214e-04 -0.602823
# 37       hsa-miR-17-3p|0  ENST00000411734  0.590726  9.188853e-04 -0.633468
# ...                  ...              ...       ...           ...       ...
# 260      hsa-miR-16-5p|0  ENST00000253462 -0.642742  2.380361e-04  0.460484
# 194    hsa-miR-200b-3p|0  ENST00000539065  0.792339  6.526293e-07 -0.200806
# 64     hsa-miR-203a-3p|0  ENST00000251691  0.910484  9.843397e-12  0.190322
# 1631    hsa-miR-140-3p|0  ENST00000441159  0.429839  1.994564e-02 -0.528629
# 499      hsa-miR-17-3p|0  ENST00000374118  0.529839  3.465116e-03 -0.534678
#
#       ExpPvalue  Statistic    Pvalue  AdjPvalue  PermutePvalue  \
# 78     0.005202  -1.331632  0.000047   0.192856   0.000000e+00
# 31     0.812752  -1.433835  0.000012   0.144639   4.094359e-07
# 16     0.211125   1.563425  0.000002   0.124570   9.212307e-07
# 46     0.000685   1.409192  0.000017   0.166352   9.212307e-07
# 37     0.000308   1.425967  0.000013   0.150200   9.212307e-07
# ...         ...        ...       ...        ...            ...
# 260    0.012234  -1.260757  0.000117   0.235819   2.139302e-05
# 194    0.286194   1.281256  0.000091   0.225960   2.190482e-05
# 64     0.312297   1.337675  0.000044   0.190863   1.924348e-05
# 1631   0.003550   1.047939  0.001367   0.410701   1.924348e-05
# 499    0.003144   1.186593  0.000289   0.289130   2.231425e-05
#
#       AdjPermutePvalue
# 78            0.000000
# 31            0.033333
# 16            0.034615
# 46            0.034615
# 37            0.034615
# ...                ...
# 260           0.050000
# 194           0.050000
# 64            0.050000
# 1631          0.050000
# 499           0.050000
#
# [193 rows x 11 columns]

# %%
ts_n_hyper = pvalue_cutoff(wrapped_hypergeom(ts_n), 'AdjPvalue')
ts_n_hyper.to_csv(OUTPUT_PATH/'hypergeom/10_ts.csv', index=False)
ts_n_hyper
# Out:
#               Molecule  Diff  Total  Proportion        Pvalue     AdjPvalue
# 7     hsa-miR-140-3p|0    35   4523    0.007738  0.000000e+00  0.000000e+00
# 10    hsa-miR-205-5p|0    19   4036    0.004708  5.773160e-15  6.542914e-14
# 0    hsa-miR-151a-3p|0    16   2423    0.006603  5.218048e-15  8.870682e-14
# 8    hsa-miR-203a-3p|0    15   5086    0.002949  2.661335e-09  2.262135e-08
# 3      hsa-miR-17-3p|0    13   5027    0.002586  1.408111e-07  9.575154e-07
# 2   hsa-miR-203a-3p|+1    12   4941    0.002429  8.259282e-07  4.680260e-06
# 15   hsa-miR-140-3p|+1    11   4981    0.002208  5.839060e-06  2.836115e-05
# 4     hsa-miR-22-3p|+1     8   3567    0.002243  1.003333e-04  4.264166e-04
# 5    hsa-miR-200c-3p|0     8   4311    0.001856  3.570190e-04  1.277752e-03
# 1    hsa-miR-200b-3p|0     8   4311    0.001856  3.570190e-04  1.277752e-03
# 13   hsa-miR-200a-3p|0     6   4423    0.001357  8.713842e-03  2.468922e-02
# 26     hsa-miR-16-5p|0     6   4621    0.001298  1.064045e-02  2.782887e-02
# 9    hsa-miR-200a-5p|0     6   3488    0.001720  2.825146e-03  8.732268e-03

# %% [markdown]
# RNA22

# %%
rna22_n = rc(OUTPUT_PATH/'experiments/10/ztest_rna22.csv')
rna22_n = adjust_permute(rna22_n)
# Out:
# Pairs: 513659 | after cut: 118

# %%
pvalue_cutoff(rna22_n, 'AdjPermutePvalue')

# %%
rna22_n_hyper = pvalue_cutoff(wrapped_hypergeom(rna22_n), 'AdjPvalue')
rna22_n_hyper.to_csv(OUTPUT_PATH/'hypergeom/10_rna22.csv', index=False)
rna22_n_hyper
# Out:
#              Molecule  Diff  Total  Proportion        Pvalue     AdjPvalue
# 0   hsa-miR-151a-3p|0    39   4919    0.007928  0.000000e+00  0.000000e+00
# 2    hsa-miR-205-5p|0    15   6065    0.002473  1.373157e-11  1.922420e-10
# 1    hsa-miR-140-3p|0    10   2464    0.004058  3.861773e-10  3.604322e-09
# 7     hsa-miR-17-3p|0     7   4652    0.001505  1.093004e-04  7.651029e-04
# 5   hsa-miR-200a-5p|0     6   4596    0.001305  7.181284e-04  4.021519e-03
# 3   hsa-miR-140-3p|+1     4   3128    0.001279  6.080639e-03  2.432255e-02
# 14  hsa-miR-200a-3p|0     3   1474    0.002035  4.925605e-03  2.298616e-02
